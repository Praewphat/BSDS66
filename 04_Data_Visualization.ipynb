# %% [markdown]
# <a href="https://colab.research.google.com/github/Praewphat/BSDS66/blob/main/04_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization

# %% [markdown]
# <div align="center"> <h1 align="center"> Visualization: <p>
# The activity of forming a mental model of something <p>
# - R. Spence, Information Visualization </h1> </div>

# %% [markdown]
# <p align="center" width="100%">
#     <img width="70%" src="https://cdn.thenewstack.io/media/2023/01/285d68dd-charts-1024x581.jpg">
# </p>

# %% [markdown]
# <details>
# <summary><font size="4">What is data visualization?</font></summary>
# <p>
# <font size="3">
#   📊 What data looks like <p>
#   📊 Expressing numerical relations <p>
#   📊 Understanding data <p>
#   📊 Compressing data <p>
#   📊 Understable <p>
#   📊 Patterns <p>
#   📊 Communications
# </font>
# </details>

# %% [markdown]
# <h3>The Importance of Data Visualization Ilustrated by Anscombe's Quartet</h3>
#
# <p align="center" width="50%">
# <img width="60%" src="https://builtin.com/sites/www.builtin.com/files/styles/ckeditor_optimize/public/inline-images/3_anscombe%27s-quartet.png">
# </p>
#
# The statistical information for these four data sets are approximately similar, but their scatter plots show that
#
# <p align="center" width="50%">
# <img width="70%" src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ec/Anscombe%27s_quartet_3.svg/1600px-Anscombe%27s_quartet_3.svg.png">
# </p>
#
# 🟢   Data Set 1 fits the linear regression model pretty well <p>
# 🔵   Data Set 2 cannot fit the linear regression model because the data is non-linear <p>
# 🔴   Data Set 3 shows the outliers involved in the data set, which cannot be handled by the linear regression model. <p>
# 🟡   Data Set 4 shows the outliers involved in the data set, which also cannot be handled by the linear regression model.

# %% [markdown]
# <h3>Types of Data Presentation (Statistical Data Presentation, In and Lee 2017)</h3>
#
# <h4>🔤 Text</h4>
#     <p>If one wishes to <font color='red'>compare or introduce two values at a certain time point</font>, it is appropriate to use text or the written language
# <h4>🗓️ Tabular forms</h4>
#     <p>Table is the most appropriate when <font color='red'>all information requires equal attention</font>, and it allows readers to selectively look at information of their own interest
# <h4>📈 Graphical forms</h4>
#     <p>Graphs allow readers to understand <font color='red'>the overall trend in data</font>, and intuitively understand <font color='red'>the comparison results between two groups</font>

# %% [markdown]
# <h3>Text</h3>
#
# *   The incidence rate of delirium following anesthesia was 11% in 2016 and 15% in 2017; no significant difference of incidence rates was found between the two years.
# *   Percentage of children with a marrtied stay-at-home mother with a working houseband
# <p align="center" width="50%">
# <img width="70%" src="https://i.imgur.com/KKyWj9J.png">
# </p>

# %% [markdown]
# <h3>Table</h3>
#
# *   Data stands out more than the structural components of the table in the second and third iteration (light borders, minimal borders)
# <p align="center" width="50%">
# <img width="70%" src="https://i.imgur.com/MUUwhlH.png">
# </p>
#
# *   The strength of tables is that they can accurately present information that cannot be presented with a graph, i.e. “132.145852”
# <p align="center" width="70%">
# <img width="70%" src="https://i.imgur.com/agZFC7x.png">
# </p>
#
# *   Heat maps for better visualization of information
# <p align="center" width="50%">
# <img width="40%" src="https://i.imgur.com/2AmBJgZ.png">
# </p>

# %% [markdown]
# <h3>Graph</h3>
#
# *   Graphs simplify complex information by using images and emphasizing data patterns or trends
#
# *   Graphs are useful for summarizing, explaining, or exploring quantitative data
#
# *   A graph format that best presents information must be chosen so that readers and reviewers can easily understand the information
#
# *   Pie Chart
#
# <p align="center" width="50%">
# <img src="https://images.squarespace-cdn.com/content/v1/5ab3d6f89f877079e13aeac1/1628341781770-QJP999091RADTBQX7F27/rule_4_pizza_race_over_under_pl-01.png?format=1000w" width="450"/>
# <img src="http://static3.businessinsider.com/image/50b62b796bb3f7084c00000e-548-411/fox-news-graph-fail.png" width="450"/>
# </p>
#
# *   Bar Chart
#
# <p align="center" width="50%">
# <img src="https://flowingdata.com/wp-content/uploads/2012/08/Bush-cuts.png" width="530">
# <img src="https://flowingdata.com/wp-content/uploads/2012/08/Fox-chart-corrected.png" width="280"/>
# </p>
#
# *   Line Chart
#
#     ⚠   Fox News reported unemployment rate during Obama Era
#
#       <p align="center" width="80%">
#       <img src="https://flowingdata.com/wp-content/uploads/2011/12/unemployment-chart-by-fox-news.jpg" width="420"/> <img src="https://flowingdata.com/wp-content/uploads/2011/12/good-chart1.png" width="540"/>
#       </p>
#
#     ⚠   Tim Cook showed a simplified chart to show the rise of Apple sales
#
#       <p align="center" width="50%">
#       <img src="https://i.kinja-img.com/gawker-media/image/upload/c_fit,f_auto,g_center,q_60,w_645/bde5cd2f6571edce63516b043215b3d8.jpg" width="450"/> <img src="https://i.kinja-img.com/gawker-media/image/upload/c_fit,f_auto,g_center,q_60,w_645/d032839e447dca8750f6c32c4e9e26c4.jpg" width="495"/>
#       </p>
#
# *   Histogram
#
# <p align="center" width="80%">
# <img src="https://aakinshin.net/posts/misleading-histograms/img/hist-bandwidth1-light.svg" width="800">
# <img src="https://bam.files.bbci.co.uk/bam/live/content/zx4mtfr/medium" width="600">
# </p>
#
# *   Box-and-Whisker Plot
#
# <p align="center" width="80%">
# <img src="https://www.statisticsfromatoz.com/uploads/7/3/2/1/73216723/boxplot_orig.png" width="800">
# </p>

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * Wonderful module for data manipulation and data analysis: https://pandas.pydata.org/docs/getting_started/index.html#getting-started
# * Great visualization module: https://matplotlib.org/
# * Pretty plots using Seaborn: https://seaborn.pydata.org/index.html
# * Plots in Pandas: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html

# %% [markdown]
# ## Allow Google Colab to access Google Drive
# Step 1: Add a shortcut of working folder to "My Drive" \
# Step 2: Mount Google Drive to Google Colab to allow Colab to access your Google Drive

# %%
from google.colab import drive # เชื่อม google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Read data
# https://www.kaggle.com/datasets/imdevskp/corona-virus-report?select=covid_19_clean_complete.csv

# %%
covid = pd.read_csv("/content/drive/MyDrive/BSDS66/covid_19_clean_complete.csv")

# %%
covid
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %%
covid['Date'] = pd.to_datetime(covid['Date'], format='%Y-%m-%d') #object -->  date time

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  datetime64[ns]
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(3)
# memory usage: 3.7+ MB

# %% [markdown]
# ## Create data visualization

# %% [markdown]
# ### Pie Chart
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.pie.html

# %% [markdown]
# * Create a pie chart of the total number of Confirmed in each WHO Region

# %%
covid.groupby("WHO Region").sum()
# Out:
# <ipython-input-7-c31348b3bd04>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   covid.groupby("WHO Region").sum()
#                                  Lat          Long  Confirmed    Deaths  \
# WHO Region
# Africa                   4727.394420  1.417872e+05   21791827    439978
# Americas               161412.174448 -6.703710e+05  402261194  19359292
# Eastern Mediterranean  108204.921108  1.697810e+05   74082892   1924029
# Europe                 567986.485104  1.032586e+05  248879793  19271040
# South-East Asia         26161.732764  1.757034e+05   55118365   1458134
# Western Pacific        183217.578356  1.234324e+06   26374411    932430
#
#                        Recovered     Active
# WHO Region
# Africa                  11193730   10158119
# Americas               157069444  225832458
# ...

# %%
covid.groupby("WHO Region").sum()[["Confirmed"]]
# Out:
# <ipython-input-8-226a847eca9c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   covid.groupby("WHO Region").sum()[["Confirmed"]]
#                        Confirmed
# WHO Region
# Africa                  21791827
# Americas               402261194
# Eastern Mediterranean   74082892
# Europe                 248879793
# South-East Asia         55118365
# Western Pacific         26374411

# %%
total_confirmed_region = covid.groupby("WHO Region").sum()[["Confirmed"]]
total_confirmed_region = total_confirmed_region.sort_values(by = "Confirmed", ascending = False)
total_confirmed_region
# Out:
# <ipython-input-9-9bf6e6fbef19>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_confirmed_region = covid.groupby("WHO Region").sum()[["Confirmed"]]
#                        Confirmed
# WHO Region
# Americas               402261194
# Europe                 248879793
# Eastern Mediterranean   74082892
# South-East Asia         55118365
# Western Pacific         26374411
# Africa                  21791827

# %%
total_confirmed_region.plot.pie(y = "Confirmed", figsize = (6,6))
#plt.legend(loc = "lower left")
# Out:
# <Axes: ylabel='Confirmed'>

# %%
total_confirmed_region.plot.pie(y = "Confirmed", figsize = (5,5),
                                autopct="%.2f%%",
                                legend="", ylabel="",
                                title="Total Confirmed by each WHO Region")
# Out:
# <Axes: title={'center': 'Total Confirmed by each WHO Region'}>

# %%
total_confirmed = total_confirmed_region["Confirmed"].sum()
total_confirmed_region.plot.pie(y = "Confirmed", figsize = (5,5), fontsize = 7,
                                autopct = lambda x : '{:,.0f} ({:.2f}%)'.format(x*total_confirmed/100, x),
                                #autopct = lambda x : '{:,.0f} \n({:.2f}%)'.format(x*total_confirmed/100, x),
                                legend = "", ylabel = "",
                                title = "Total Confirmed by WHO Region")
# Out:
# <Axes: title={'center': 'Total Confirmed by WHO Region'}>

# %% [markdown]
# <font color='red'><h4>📝 Your turn</h4></font>
# <p>Create a pie chart of the total number of Deaths in each WHO Region

# %%
# compute the total number of Deaths in each WHO Region
covid.groupby("WHO Region").sum()[["Deaths"]]
# Out:
# <ipython-input-13-0ca40c2dc795>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   covid.groupby("WHO Region").sum()[["Deaths"]]
#                          Deaths
# WHO Region
# Africa                   439978
# Americas               19359292
# Eastern Mediterranean   1924029
# Europe                 19271040
# South-East Asia         1458134
# Western Pacific          932430

# %%
# plot a pie chart
covid.groupby("WHO Region").sum()[["Deaths"]].plot.pie(y="Deaths")
# Out:
# <ipython-input-14-f57a782c1e02>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   covid.groupby("WHO Region").sum()[["Deaths"]].plot.pie(y="Deaths")
# <Axes: ylabel='Deaths'>

# %% [markdown]
# ### Scatter Plot
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.scatter.html

# %% [markdown]
# * Explore the relationship between the average daily number of Confirmed, Deaths, Recovered, and Active in each WHO region

# %%
covid.groupby("WHO Region").mean()
# Out:
# <ipython-input-15-c6674cf78441>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   covid.groupby("WHO Region").mean()
#                              Lat        Long     Confirmed       Deaths  \
# WHO Region
# Africa                  0.523869   15.712238   2414.874446    48.756427
# Americas               18.664683  -77.517460  46514.939177  2238.586031
# Eastern Mediterranean  26.161731   41.049556  17911.724371   465.190764
# Europe                 37.765059    6.865596  16547.858577  1281.319149
# South-East Asia        13.915815   93.459266  29318.279255   775.603191
# Western Pacific        17.719302  119.373725   2550.716731    90.176983
#
#                           Recovered        Active
# WHO Region
# Africa                  1240.439938   1125.678081
# ...

# %%
daily_country = covid.groupby("WHO Region").mean()[["Confirmed","Deaths","Recovered","Active"]]
daily_country
# Out:
# <ipython-input-16-60c80428640b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   daily_country = covid.groupby("WHO Region").mean()[["Confirmed","Deaths","Recovered","Active"]]
#                           Confirmed       Deaths     Recovered        Active
# WHO Region
# Africa                  2414.874446    48.756427   1240.439938   1125.678081
# Americas               46514.939177  2238.586031  18162.516651  26113.836494
# Eastern Mediterranean  17911.724371   465.190764  11617.674807   5828.858801
# Europe                 16547.858577  1281.319149   8191.627327   7074.912101
# South-East Asia        29318.279255   775.603191  15973.578191  12569.097872
# Western Pacific         2550.716731    90.176983   1824.173114    636.366634

# %%
daily_country.plot.scatter(x="Confirmed", y="Deaths")
# Out:
# <Axes: xlabel='Confirmed', ylabel='Deaths'>

# %% [markdown]
# Plot color, marker, and line format: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
daily_country.plot.scatter(x = "Confirmed", y = "Deaths",
                           alpha = 0.6, c = "g", marker = "x",
                           title = "Average Confirmed vs. Deaths by WHO Regions",
                           xlabel = "Number of Cases",
                           ylabel = "Number of Deaths")
# Out:
# <Axes: title={'center': 'Average Confirmed vs. Deaths by WHO Regions'}, xlabel='Number of Cases', ylabel='Number of Deaths'>

# %%
daily_country.plot.scatter(x = "Confirmed", y = "Deaths", alpha = 0.6,
                           title = "Average Confirmed vs. Deaths by WHO Regions",
                           xlabel = "Number of Cases",
                           ylabel = "Number of Deaths")
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.text.html
for i in range(daily_country.shape[0]):
  plt.text(x = daily_country["Confirmed"][i] - 2000,
           y = daily_country["Deaths"][i] + 50,
           s = list(daily_country.index)[i],
           fontsize = "x-small")

# %% [markdown]
# <font color='red'><h4>📝 Your turn</h4></font>
# <p>Create a scatter plot of the average daily number of Confirmed and Recovered for each WHO region

# %%
# Scatter plot
daily_country.plot.scatter(x = "Confirmed", y = "Recovered", alpha = 0.6,
                           title = "Average Confirmed vs. Recovered by WHO Regions",
                           xlabel = "Number of Cases",
                           ylabel = "Number of Recovered")
# Out:
# <Axes: title={'center': 'Average Confirmed vs. Recovered by WHO Regions'}, xlabel='Number of Cases', ylabel='Number of Recovered'>

# %% [markdown]
# Create several scatter plots simultaneously using pandas.plotting

# %%
pd.plotting.scatter_matrix(daily_country)
# Out:
# array([[<Axes: xlabel='Confirmed', ylabel='Confirmed'>,
#         <Axes: xlabel='Deaths', ylabel='Confirmed'>,
#         <Axes: xlabel='Recovered', ylabel='Confirmed'>,
#         <Axes: xlabel='Active', ylabel='Confirmed'>],
#        [<Axes: xlabel='Confirmed', ylabel='Deaths'>,
#         <Axes: xlabel='Deaths', ylabel='Deaths'>,
#         <Axes: xlabel='Recovered', ylabel='Deaths'>,
#         <Axes: xlabel='Active', ylabel='Deaths'>],
#        [<Axes: xlabel='Confirmed', ylabel='Recovered'>,
#         <Axes: xlabel='Deaths', ylabel='Recovered'>,
#         <Axes: xlabel='Recovered', ylabel='Recovered'>,
#         <Axes: xlabel='Active', ylabel='Recovered'>],
#        [<Axes: xlabel='Confirmed', ylabel='Active'>,
#         <Axes: xlabel='Deaths', ylabel='Active'>,
#         <Axes: xlabel='Recovered', ylabel='Active'>,
#         <Axes: xlabel='Active', ylabel='Active'>]], dtype=object)

# %% [markdown]
# ### Line Plot
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.line.html

# %% [markdown]
# * Explore the daily trend of the number of Confirmed, Deaths, Recovered, and Active in Thailand

# %%
# Select data from Thailand
covidTH = covid.loc[covid["Country/Region"]=="Thailand",:]
# covid[covid["Country/Region"]=="Thailand"]
covidTH
# Out:
#       Province/State Country/Region        Lat        Long       Date  \
# 207              NaN       Thailand  15.870032  100.992541 2020-01-22
# 468              NaN       Thailand  15.870032  100.992541 2020-01-23
# 729              NaN       Thailand  15.870032  100.992541 2020-01-24
# 990              NaN       Thailand  15.870032  100.992541 2020-01-25
# 1251             NaN       Thailand  15.870032  100.992541 2020-01-26
# ...              ...            ...        ...         ...        ...
# 47970            NaN       Thailand  15.870032  100.992541 2020-07-23
# 48231            NaN       Thailand  15.870032  100.992541 2020-07-24
# 48492            NaN       Thailand  15.870032  100.992541 2020-07-25
# 48753            NaN       Thailand  15.870032  100.992541 2020-07-26
# 49014            NaN       Thailand  15.870032  100.992541 2020-07-27
#
#        Confirmed  Deaths  Recovered  Active       WHO Region
# 207            2       0          0       2  South-East Asia
# ...

# %%
daily_covidTH = covidTH.groupby("Date").mean()[["Confirmed","Deaths","Recovered","Active"]]
daily_covidTH
# Out:
# <ipython-input-23-216976c026ef>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   daily_covidTH = covidTH.groupby("Date").mean()[["Confirmed","Deaths","Recovered","Active"]]
#             Confirmed  Deaths  Recovered  Active
# Date
# 2020-01-22        2.0     0.0        0.0     2.0
# 2020-01-23        3.0     0.0        0.0     3.0
# 2020-01-24        5.0     0.0        0.0     5.0
# 2020-01-25        7.0     0.0        0.0     7.0
# 2020-01-26        8.0     0.0        2.0     6.0
# ...               ...     ...        ...     ...
# 2020-07-23     3279.0    58.0     3107.0   114.0
# 2020-07-24     3279.0    58.0     3107.0   114.0
# 2020-07-25     3282.0    58.0     3109.0   115.0
# 2020-07-26     3291.0    58.0     3109.0   124.0
# 2020-07-27     3297.0    58.0     3111.0   128.0
#
# ...

# %%
daily_covidTH.plot.line()
# Out:
# <Axes: xlabel='Date'>

# %%
daily_covidTH.plot.line(style='--')
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# <font color='red'><h4>📝 Your turn</h4></font>
# <p>Create a line plot of the number of countries with death occurred daily

# %%
# summarize the daily number of countries with death occurred

# select only records having Deaths > 0
deaths_occurred = covid.loc[covid["Deaths"]>0, :]
deaths_occurred
# Out:
#       Province/State         Country/Region        Lat        Long       Date  \
# 61             Hubei                  China  30.975600  112.270700 2020-01-22
# 318            Hebei                  China  39.549000  116.130600 2020-01-23
# 322            Hubei                  China  30.975600  112.270700 2020-01-23
# 579            Hebei                  China  39.549000  116.130600 2020-01-24
# 580     Heilongjiang                  China  47.862000  127.761500 2020-01-24
# ...              ...                    ...        ...         ...        ...
# 49063            NaN  Sao Tome and Principe   0.186400    6.613100 2020-07-27
# 49064            NaN                  Yemen  15.552727   48.516388 2020-07-27
# 49065            NaN                Comoros -11.645500   43.333300 2020-07-27
# 49066            NaN             Tajikistan  38.861000   71.276100 2020-07-27
# 49067            NaN                Lesotho -29.610000   28.233600 2020-07-27
#
# ...

# %%
# count the number of countries with deaths occurred in each day
count_country_deaths = deaths_occurred.groupby("Date")[["Country/Region"]].count()
count_country_deaths
# Out:
#             Country/Region
# Date
# 2020-01-22               1
# 2020-01-23               2
# 2020-01-24               3
# 2020-01-25               3
# 2020-01-26               5
# ...                    ...
# 2020-07-23             225
# 2020-07-24             226
# 2020-07-25             226
# 2020-07-26             226
# 2020-07-27             226
#
# [188 rows x 1 columns]

# %%
# create a line plot
count_country_deaths.plot.line()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Bar Chart
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.barh.html

# %% [markdown]
# * Create a bar plot of the daily average number of Confirmed and Deaths in countries in "Western Pacific" WHO Region

# %%
# selection countries in Western Pacific
covidWP = covid.loc[covid["WHO Region"]=="Western Pacific", :]
covidWP
# Out:
#                      Province/State Country/Region        Lat        Long  \
# 8      Australian Capital Territory      Australia -35.473500  149.012400
# 9                   New South Wales      Australia -33.868800  151.209300
# 10               Northern Territory      Australia -12.463400  130.845600
# 11                       Queensland      Australia -27.469800  153.025100
# 12                  South Australia      Australia -34.928500  138.600700
# ...                             ...            ...        ...         ...
# 48987                           NaN    Philippines  12.879721  121.774017
# 49001                           NaN      Singapore   1.283300  103.833300
# 49012                           NaN        Taiwan*  23.700000  121.000000
# 49033                           NaN        Vietnam  14.058324  108.277199
# 49042                           NaN           Laos  19.856270  102.495496
#
#             Date  Confirmed  Deaths  Recovered  Active       WHO Region
# ...

# %%
# summarize daily average number of Confirmed and Deaths in each country
covidWP.groupby("Country/Region").mean()
# Out:
# <ipython-input-30-2229ee109da9>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   covidWP.groupby("Country/Region").mean()
#                         Lat        Long     Confirmed      Deaths  \
# Country/Region
# Australia        -32.106275  141.355488    638.462101    7.571144
# Brunei             4.535300  114.727700     96.638298    1.202128
# Cambodia          11.550000  104.916700     90.845745    0.000000
# China             32.887645  111.785991   2277.885558  108.383785
# Fiji             -17.713400  178.065000     12.053191    0.000000
# Japan             36.204824  138.252924  10385.611702  455.101064
# Laos              19.856270  102.495496     11.856383    0.000000
# Malaysia           4.210484  101.975766   4664.223404   68.994681
# ...

# %%
# select only the columns that we need
covidWP_summary = covidWP.groupby("Country/Region").mean()[["Confirmed", "Deaths"]]
covidWP_summary
# Out:
# <ipython-input-31-325d30437c54>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   covidWP_summary = covidWP.groupby("Country/Region").mean()[["Confirmed", "Deaths"]]
#                      Confirmed      Deaths
# Country/Region
# Australia           638.462101    7.571144
# Brunei               96.638298    1.202128
# Cambodia             90.845745    0.000000
# China              2277.885558  108.383785
# Fiji                 12.053191    0.000000
# Japan             10385.611702  455.101064
# Laos                 11.856383    0.000000
# Malaysia           4664.223404   68.994681
# Mongolia             90.420213    0.000000
# New Zealand         936.058511   11.601064
# Papua New Guinea      6.303191    0.010638
# Philippines       15811.760638  589.851064
# ...

# %%
covidWP_summary.plot.bar()
# Out:
# <Axes: xlabel='Country/Region'>

# %%
# horizontal bar plot
covidWP_summary.plot.barh(color = ["green","orange"])
# Out:
# <Axes: ylabel='Country/Region'>

# %%
covidWP_summary.plot.bar(stacked = True)
# Out:
# <Axes: xlabel='Country/Region'>

# %% [markdown]
# <font color='red'><h4>📝 Your turn</h4></font>
# <p>Create a bar plot of the daily average number of Confirmed and Deaths in each WHO Region sorted decreasingly from largest to smallest values of Confirmed

# %%
# summarize the daily average number of Confirmed and Deaths in each WHO Region
covid.groupby("WHO Region")[["Confirmed", "Deaths"]].mean()
# Out:
#                           Confirmed       Deaths
# WHO Region
# Africa                  2414.874446    48.756427
# Americas               46514.939177  2238.586031
# Eastern Mediterranean  17911.724371   465.190764
# Europe                 16547.858577  1281.319149
# South-East Asia        29318.279255   775.603191
# Western Pacific         2550.716731    90.176983

# %%
# sort values decreasingly from largest to smallest values of Confirmed
covid.groupby("WHO Region")[["Confirmed", "Deaths"]].mean().sort_values(by = "Confirmed", ascending = False)
# Out:
#                           Confirmed       Deaths
# WHO Region
# Americas               46514.939177  2238.586031
# South-East Asia        29318.279255   775.603191
# Eastern Mediterranean  17911.724371   465.190764
# Europe                 16547.858577  1281.319149
# Western Pacific         2550.716731    90.176983
# Africa                  2414.874446    48.756427

# %%
# create a bar plot
covid.groupby("WHO Region")[["Confirmed", "Deaths"]].mean().sort_values(by = "Confirmed", ascending = False).plot.bar()
# Out:
# <Axes: xlabel='WHO Region'>

# %% [markdown]
# ### Histogram
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.hist.html

# %% [markdown]
# * Plot a histogram of the daily number of Deaths in Thailand

# %%
daily_covidTH
# Out:
#             Confirmed  Deaths  Recovered  Active
# Date
# 2020-01-22        2.0     0.0        0.0     2.0
# 2020-01-23        3.0     0.0        0.0     3.0
# 2020-01-24        5.0     0.0        0.0     5.0
# 2020-01-25        7.0     0.0        0.0     7.0
# 2020-01-26        8.0     0.0        2.0     6.0
# ...               ...     ...        ...     ...
# 2020-07-23     3279.0    58.0     3107.0   114.0
# 2020-07-24     3279.0    58.0     3107.0   114.0
# 2020-07-25     3282.0    58.0     3109.0   115.0
# 2020-07-26     3291.0    58.0     3109.0   124.0
# 2020-07-27     3297.0    58.0     3111.0   128.0
#
# [188 rows x 4 columns]

# %%
daily_covidTH[["Deaths"]].plot.hist(color = "red")
# Out:
# <Axes: ylabel='Frequency'>

# %%
np.arange(start=0,stop=70,step=10)
# Out:
# array([ 0, 10, 20, 30, 40, 50, 60])

# %%
daily_covidTH[["Deaths"]].plot.hist(bins = np.arange(start=0,stop=70,step=10))
# Out:
# <Axes: ylabel='Frequency'>

# %%
daily_covidTH[["Deaths"]].plot.hist(bins = 15)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# perform similar selection of computing the average daily values of Confirmed, Deaths, Recovered, and Active in Taiwan
covidTW = covid.loc[covid["Country/Region"]=="Taiwan*",:]
daily_covidTW = covidTW.groupby("Date").mean()[["Confirmed","Deaths","Recovered","Active"]]
daily_covidTW
# Out:
# <ipython-input-43-cd6b90839883>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   daily_covidTW = covidTW.groupby("Date").mean()[["Confirmed","Deaths","Recovered","Active"]]
#             Confirmed  Deaths  Recovered  Active
# Date
# 2020-01-22        1.0     0.0        0.0     1.0
# 2020-01-23        1.0     0.0        0.0     1.0
# 2020-01-24        3.0     0.0        0.0     3.0
# 2020-01-25        3.0     0.0        0.0     3.0
# 2020-01-26        4.0     0.0        0.0     4.0
# ...               ...     ...        ...     ...
# 2020-07-23      455.0     7.0      440.0     8.0
# 2020-07-24      458.0     7.0      440.0    11.0
# 2020-07-25      458.0     7.0      440.0    11.0
# 2020-07-26      458.0     7.0      440.0    11.0
# 2020-07-27      462.0     7.0      440.0    15.0
#
# ...

# %%
# create a new data frame with the daily average number of Deaths of Thailand and Taiwan
Confirmed_TH_TW = pd.DataFrame({"Thailand": daily_covidTH["Deaths"], "Taiwan": daily_covidTW["Deaths"]})
Confirmed_TH_TW
# Out:
#             Thailand  Taiwan
# Date
# 2020-01-22       0.0     0.0
# 2020-01-23       0.0     0.0
# 2020-01-24       0.0     0.0
# 2020-01-25       0.0     0.0
# 2020-01-26       0.0     0.0
# ...              ...     ...
# 2020-07-23      58.0     7.0
# 2020-07-24      58.0     7.0
# 2020-07-25      58.0     7.0
# 2020-07-26      58.0     7.0
# 2020-07-27      58.0     7.0
#
# [188 rows x 2 columns]

# %%
Confirmed_TH_TW.plot.hist(alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# perform similar selection of computing the average daily values of Confirmed, Deaths, Recovered, and Active in Taiwan
covidCN = covid.loc[covid["Country/Region"]=="Chaina*",:]
daily_covidCN = covidTW.groupby("Date").mean()[["Confirmed","Deaths","Recovered","Active"]]
daily_covidCN
# Out:
# <ipython-input-53-38640a65d1e8>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   daily_covidCN = covidTW.groupby("Date").mean()[["Confirmed","Deaths","Recovered","Active"]]
#             Confirmed  Deaths  Recovered  Active
# Date
# 2020-01-22        1.0     0.0        0.0     1.0
# 2020-01-23        1.0     0.0        0.0     1.0
# 2020-01-24        3.0     0.0        0.0     3.0
# 2020-01-25        3.0     0.0        0.0     3.0
# 2020-01-26        4.0     0.0        0.0     4.0
# ...               ...     ...        ...     ...
# 2020-07-23      455.0     7.0      440.0     8.0
# 2020-07-24      458.0     7.0      440.0    11.0
# 2020-07-25      458.0     7.0      440.0    11.0
# 2020-07-26      458.0     7.0      440.0    11.0
# 2020-07-27      462.0     7.0      440.0    15.0
#
# ...

# %%
daily_covidCN.plot.hist(alpha=.3)
# Out:
# <Axes: ylabel='Frequency'>

# %%
daily_covidCN.hist(alpha=.3)
# Out:
# array([[<Axes: title={'center': 'Confirmed'}>,
#         <Axes: title={'center': 'Deaths'}>],
#        [<Axes: title={'center': 'Recovered'}>,
#         <Axes: title={'center': 'Active'}>]], dtype=object)

# %% [markdown]
# <font color='red'><h4>📝 Your turn</h4></font>
# <p>Create a histogram plot of the daily average number of Confirmed in Thailand

# %%
daily_covidTH
# Out:
#             Confirmed  Deaths  Recovered  Active
# Date
# 2020-01-22        2.0     0.0        0.0     2.0
# 2020-01-23        3.0     0.0        0.0     3.0
# 2020-01-24        5.0     0.0        0.0     5.0
# 2020-01-25        7.0     0.0        0.0     7.0
# 2020-01-26        8.0     0.0        2.0     6.0
# ...               ...     ...        ...     ...
# 2020-07-23     3279.0    58.0     3107.0   114.0
# 2020-07-24     3279.0    58.0     3107.0   114.0
# 2020-07-25     3282.0    58.0     3109.0   115.0
# 2020-07-26     3291.0    58.0     3109.0   124.0
# 2020-07-27     3297.0    58.0     3111.0   128.0
#
# [188 rows x 4 columns]

# %%
daily_covidTH[["Confirmed"]].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Box Plot
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.box.html

# %%
daily_covidTH.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# <font color='red'><h4>📝 Your turn</h4></font>
# <p>Create a box plot of the average number of Confirmed daily (groupby Date)

# %%
# group data by Date
covid.groupby("Date")[["Confirmed"]].mean()
# Out:
#                Confirmed
# Date
# 2020-01-22      2.126437
# 2020-01-23      2.505747
# 2020-01-24      3.605364
# 2020-01-25      5.494253
# 2020-01-26      8.114943
# ...                  ...
# 2020-07-23  59427.130268
# 2020-07-24  60504.386973
# 2020-07-25  61483.486590
# 2020-07-26  62267.417625
# 2020-07-27  63143.620690
#
# [188 rows x 1 columns]

# %%
# create a box plot
covid.groupby("Date")[["Confirmed"]].mean().plot.box()
# Out:
# <Axes: >

# %%
#แต่ละประเทศในข้อมูล มีจำนวน confirmed และ Deaths ทั้งหมดอย่างไร นำเสนอด้วย boxplot

# %%
# create a box plot
covid.groupby("Country/Region")[["Confirmed","Deaths"]].sum().plot.box()
# Out:
# <Axes: >

# %% [markdown]
# <h4>Plot options</h4>
#
#
# *   https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot
# *   https://matplotlib.org/cheatsheets/
#     - https://matplotlib.org/cheatsheets/cheatsheets.pdf
#     - https://matplotlib.org/cheatsheets/handout-beginner.pdf
